# %%
jupter notebook-markdown-latex-numpy-pandas(基于np)-数据分析

# %%
tab+M快速转为markdown格式的单元格
shift+M合并单元格

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
a=4

# %%
a
# Out:
# 4

# %% [markdown]
# # 一级标题

# %% [markdown]
# #### 四级标题

# %% [markdown]
# **粗体（两星）示意**

# %% [markdown]
# *斜体（一星）示意*

# %% [markdown]
# ~~我被删除（两波浪）了~~

# %% [markdown]
# 换行
# 两空

# %% [markdown]
# [我的主页地址](https：//space.bilibili.com/523995133)  []()

# %% [markdown]
# ![城市景观](https://img0.baidu.com/it/u=25183460,870873689&fm=253)

# %% [markdown]
# ```python
# import math
# print("Hello World!")
# print(math.pi)
# ```

# %% [markdown]
# letax加减乘除
# $$x + y$$
# $$x- y$$
# $$x\timesy$$
# $$x\div y$$

# %%
letax上标下标
$$x^3$$
$$H_20$$
$$S_{input}$$

# %%
letax求和求根
$$\sum(x^2 + y^2)$$
$$\sqrt[3]x$$
$$\sqrt[3]{a^2m^2}$$

# %%
letax分数线
$$\frac{x+yHx-y}$$

# %%
import numpy as np numpynumpynumpynumpynumpynumpynumpynumpy

# %%
np.arange(5, 10, 2)
# Out:
# array([5, 7, 9])

# %%
import numpy as np

# %%
arr1 = np.array([6, 2, -7, -2, 1])
arr1
# Out:
# array([ 6,  2, -7, -2,  1])

# %%
arr2=np.array([[1,3,5],[2,4,6]])
arr2
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
print(arr1.ndim)
print(arr2.ndim)
print(arrl.shape)
print(arr2.shape)
print(arrl.size)
print(arr2.size)
print(arrl.dtype)
print(arr2.dtype)
# Out:
# 1
# 2
# (5,)
# (2, 3)
# 5
# 6
# int64
# int64

# %%
arr_all_0 = np.zeros(6)
arr_all_0
# Out:
# array([0., 0., 0., 0., 0., 0.])

# %%
arr_all_1=np.ones(6)
arr_all_1
# Out:
# array([1., 1., 1., 1., 1., 1.])

# %%
arr_even=np.arange(10,21,2)
arr_even
# Out:
# array([10, 12, 14, 16, 18, 20])

# %% [markdown]
# numpy数组切片！！！！！！
# 35172631
# 01234
# arr1[1:4]array([5,17,26])

# %% [markdown]
# arr4+arr5
# arr4＊3
# arr4.max()
# arr4.min()
# arr4.sum()
# arr4.mean()
# arr[arr>6]

# %%
与或非
and or not
& | ~
arr[(arr > 6)&(arr < 10) ]

# %%
NumPy操作数组练习
import numpy as np
arrl=np.array([1,3,2,4,9])
arr2=np.ones(5)
arr3=np.zeros(3)
数组拼接arr4=np.concatenate([arr1,arr2, arr3])
排序arrl.sort()
arrl
用两种方法打印arr1的第三个元素
print(arrl[2])
print(arrl[-3])
输出从arr1第2个元素到第4个元素组成的的数组
arr1[1:4]
输出arr1与arr2的同位置元素相加后组成的数组
arr1+arr2
筛选出arr1数组里所有小于1或大于3的数字，并打印出来
arrl[(arr<1)|arrl>3)]

# %%
Pandas-Series,更强大的数组形态

# %%
import pandas as pd pandaspandaspandaspandaspandaspandaspandaspandaspandasSeries

# %%
s1=pd.Series([5,17,26,31])
s1
# Out:
# 0     5
# 1    17
# 2    26
# 3    31
# dtype: int64

# %% [markdown]
# pandas Series索引和切片类似于numpy___不同点在于标签索引和切片（标签包含最后一位），标签索引添加方法用index或字典
# 当我们用整数做索引取值或切片的时候，索引取值时按照标签，切片时按照位置
# loc表示用标签索引去取值或切片s2.loc[1:3]
# iloc表示用位置索引l去取值或切片s2.iloc[1:3]
# print(sl.index)
# print(sl.values)
# 创建一个叫s2的Series，里面包含元素1、2、3、4、5，并且对应索引引5、4、3、2、1。创建后进行输出。
# s2=pd.Series（[1,2,3,4,5],index=[5,4,3,2,1])
# s2
# 输出s2里按位置顺序排在第2个的元素。
# s2.iloc[1]
# 输出s2里按位置顺序排在第2个的元素。
# s2.1oc[5:3]
# 通过一个字典来创建Seriess3。字典的键为：小李、小陈、小张、小曾、小邓，值为82、93、91、
# 78、68。创建后进行输出。
# s3=pd.Series（{"小李”：82，“小陈"：93，“小张"：91，“小曾"：78，“小邓”：68}）
# s3
# 把s3里小张标签对应的值改为95，再输出s3。
# s3.loc["小张”]=95
# s3
# 输出s3里所有值大于80且小于90的元素
# s3[(s3>80)&(s3<90）]

# %% [markdown]
# Series之间的操作会根据索引l自动对齐的好处是,由于一般我们会利用标签索引表示不同对象的数据,那即使不同Series里数据顺序不一样,自动对齐

# %% [markdown]
# Pandas操作Series的apply得到新的元素（高阶函数）
# 创建s1，包含元素[92，67，70，88，76]及对应索引][小明”，“小红”，“小杰”，“小丽”，“小华]。创建s2，包含元素[95，85，60，79，76]及对应索引1[小明"，“小杰"，“小宇"，“小娟”，“小彤]。创建后打印s1和s2。
# s1=pd.Series（[92，67，70，88，76]，index=["小明"，“小红"，“小杰”，“小丽”]
# s2=pd.Series（[95，85，60，79，76]，index=["小明"，"小杰"，“小宇”，“小娟"]
# print(sl)
# print(s2)
# 让s1和s2的相同索引元素之间进行相加，若无法找到对应索引的值则将缺失值用0代替。
# s1.add（s2,fill_value=o)
# 输出s1的统计学相关数据，包括最大值、最小值、平均值、标准差。
# s1.describe()
# 把s1更新为所有数字加5后的结果，并进行输出。
# s1=s1+5
# 根据以下规则，输出一个新的Series，包含s1里各个学生成绩所对应的等级。ABCDE
# def get_grade_from_score(score):
#     if score>90:
#         return"A"
#     elif score>80:
#         return "B"
#     elif score>70:
#         return "C"
#     elif score>60:
#         return "D"
#     else:
#         return “不及格"
# ~~get_grade_from_score（55）~~
# s1.apply(get_gradefrom score)

# %% [markdown]
# 练习【【【【【【重要】】】】】】Pandaspandaspandaspandaspandaspandaspandaspandaspandaspandas-DataFrame
# import pandas as pd
# ![image.png](attachment:c76057fa-92b8-4b68-8f0c-a73e8af712ca.png)
# ————创建一个叫students的DataFrame.包含列名姓名、性别、身高，数据分别对应创建好的name、gender、以及height
# 这三个Series。输出创建好的students。
# students=pd.DataFrame({"姓名"：name，“性别"：gender，“身高”：height}}
# students
# ————打印students所有索引l和列名
# print(students.index)
# print(students.columns)
# ————输出把students的行和列进行转置后的结果
# students.T
# —————输出students的身高列。
# students.身高
# students["身高"]更通用,因为空格存在
# ————输出students的性别和身高列
# students[["性别”，“身高"]】
# ————输出students索引为003的行
# students.loc[003]
# ————输出students索引l为003、004、005的行
# students.loc["003":"005"]
# ————输出 students里索引为005的身高。
# students.loc["005"，“身高"]
# ————输出students索引l为003、005的数据的姓名和身高。
# students.loc[["003",“005"]，[“姓名”，“身高”]]
# ————输出students索引l为003、005的数据的所有变量
# students.loc[["003","005"],:]
# students.loc[["003"，“005"]，“姓名”："身高"]
# ————输出 students里身高大于165的女性
# students[(students["身高"]>165 & ([students["性别"=="女性"])
# ————通过head方法，输出students前五行数据。看前五行数据
# students.head()

# %% [markdown]
# Pandas-DataFrame常见操作练习
# import pandas as pd
# ————创建一个名为students的DataFrame，包含数据如下：
# {"001”：{"姓名”：“小陈”，“考试1”：85，“考试2"：95，“考试3"：92}，“002"：{“姓名”：“小李”，“考试1”：91，“考试2”：92，“考试3”：94}，“003"：《“姓名”：“小
# 王”，“考试1"：86，“考试2"：81，“考试3”：89），“004”：{“姓名”：“小张”，“考试1”：79，“考试2”：89，“考试3"：95}，“005”：{“姓名”：“小赵”，“考试1”：96，“考
# 试2"：91，“考试3"：91}，“006”：{“姓名”：“小周”，“考试1”：81，“考试2”：89，“考试3”：92}
# student_data={“001"：{“姓名”：“小陈”，“考试1"：85，“考试2”：95，“考试3”：92
# students = pd.DataFrame(student_data).T
# students
# ————给students增加一列考试4，数据依次为：[72,69,79,83,82,76]。
# students["考试4"]=[72,69,79，83，82，76]
# ————给students添加一行，索引l为o07，数据为："小杨“，79，82，81，69
# students.loc["007"]=[“小杨”,79,82.81.93]
# ————输出students删除索引为006、007的结果，但不要改变students本身。
# students.drop(["006","007"],axis=0]
# ————输出students删除列名为“考试2”、“考试4"的结果，但不要改变students本身。
# students.drop([“考试2”“考试4"]，axis=1）
# ————创建一个Seriesbonus，包含的值和值对应的索引l分别为：“考试1”：2，“考试2”：3，“考试3"：2，“考试4”：5}。输出这个Series与students里所有分数列相加后的结果，但不用更新students.
# bonus=pd.Series（{"考试1"：2，“考试2"：3，“考试3"：2，“考试4"：5}）###不同考试加分
# bonus + students[["考试1”,考试2“,“考试3“,"考试4”]]
# ————更新students的考试4，让每项数据值增加10，并输出更新后的结果。
# students[“考试4”]=students[“考试4”]+10

# %% [markdown]
# Pandas-DataFrame常见操作练习之更多丝滑操作
# import pandas as pd
# ————{”001”：{“姓名”：“小陈”，“考试1”：85，“考试2”：95，“考试3”：92}，“002”：{“姓名”：“小李”，“考试1”：91，“考试2”：92，“考试3"：94}，“003”：{“姓名”：“小王”，“考试1”：86，“考试2”：81，“考试3”：89}，“004”：{“姓名”：“小张”，“考试1”：79，“考试2”：89，“考试3”：95}，“005”：{“姓名”：“小赵”，“考试1”：96，“考试2"：91，“考试3"：91}，“006”：{“姓名”：“小周”，“考试1”：81，“考试2”：89，“考试3"：92}}
# students=pd.DataFrame（{"001"：{"姓名"：“小陈"，“考试1"：85，“考试2"：95，“考试3"：92}，“002"：...).T
# students
# ————创建一个叫student_average的DataFrame，索引为学号，包含姓名列（列名为“姓名"）以及计算出三次考试平均值后的结果列（列名为“平均分"）
# average=students.loc[：，“考试1"：“考试3"].mean(axis=1)
# name=students["姓名"]
# student average=pd.DataFrame（{"姓名”:name，“平均分":average})
# student average
# ————输出每次考试第二高的分数组成的Series，可以尝试结合匿名函数。
# import numpy as np
# students.loc[:,““考试1":"考试3"].apply（lambda x:np.sort（x）[-2])
# ————根据以下规则，输出每个学号对应的四次考试的等级
# A+：平均分>=95
# A:90<=平均分<95
# B+：85<=平均分<80
# B:80<=平均分<85
# C+：75<=平均分<80
# C:平均分<75
# def get_grade(score) :
#     if score>=95:
#         return A+
#     elif scor>=90:
#         return"A"
#     elifscore>=85:
#         return"B+
#     elifscore>=80:
#         return"B"
#     elif score>=-75:
#         return`C+
#     else:
#         return "c"
# students.loc[:，“考试1":"考试3"].applymap（get_grade)
# ————展示students每个考试分数数据列的统计信息，包括个数、平均值、标准差、四分位数等。
# #默认为object，pandas认为没有数字列
# students[“考试1"]students["考试l"].astype（'int')
# students[“考试2"]students["考试2"].astype（'int')
# students["考试3"]students["考试3"].astype（'int')
# students.describe()

# %%
数据分析-数据读取
import pandas as pd
pd.read_json("./cell_phones_survey.json")
pd.read_csv(". /fifa_players.csv")
pdread_csv("./fifa_players.csv", index_col="player_id")
pd.set_option("display.max_columns", 150)
pd.set_option("display.max_colwidth", 500)
df4=pd.read_csv(amazon.csv)
~~df4.info()~~
~~df1.describe()~~

# %%
数据分析-评估数据
import pandas as pd
1
df4 pd.read_csv(amazon.csv)
df4.info（)
列的数量
列的名字
空缺值的数量
列数据的类型
2
获取开头/结尾N行（以10行为例）
DataFrame名字.head(10)
DataFrame名字.tail（10)
3
评估丢失数据
scores[["考试2"].isnull（）.sum()
scores.isnull().sum()
提取丢失数据的行scores[scores["考试3"].isnull(）]
4
评估重复数据
students["学号"].duplicated()
students.duplicated()
students.duplicated(subset=["学号","性别"])同时重复可以确定重复
提取重复数据students[students.duplicated(subset=["学号","性别"])]
5
评估不一致数据
students["班级"].value_counts()
6
评估无效/错误数据
students["身高"].sort_values()
students.describe()

# %%
数据分析-清洗数据
0
重命名或者重排序为整洁数据——宽数据重塑、拆分为长数据
df1.rename(index={...})
df1.rename(columns={...})
df1.rename(columns={"客户_姓名":"客户姓名","客户性别":"客户性别","age":"客户年龄","邮箱":"客户邮箱"},inplace=True)
df2.rename(columns=str.upper)
pandas.Series.str.capitalize
pandas.Series.str.casefold
pandas.Series.str.cat
pandas.Series.str.center
pandas.Series.str.contains
pandas.Series.str.count
pandas.Series.str.decode
pandas.Series.str.encode
pandas.Series.str.endswith
pandas.Series.str.extract
pandas.Series.str.extractall
pandas.Series.str.ind
pandas.Series.str.indall
pandas.Series.str.ullmatch
pandas.Series.str.get
pandas.Series.str.ndex

把某列设为索引
df2.set_index("Salesperson")
df3.reset_index()
重排序df4.sort_index()
df1.sort_index(inplace=True)
1
丢失数据
人工填入，或者忽略，或者删掉不重要的缺失行，或者把平均数、中位数、众数等填充进去代替空缺
2
重复数据
删除
3
不一致数据
替换
4
无效数据
删除或替换
5
数据类型转换—
比如手机转为字符串
是或否，改为布尔值

# %%
import pandas as pd
s1=pd.Series([92,67,70,88,76],index=["小明","小红","小杰","小丽","cc"])
s2=pd.Series([95,85,60,79,76],index=["小明","小杰","小宇","小娟","dd"])

def get_grade_from_score(score):
    if score>90:
        return "A"
    elif score>80:
        return "B"
    elif score>70:
        return "C"
    elif score>60:
        return "D"
    else:
        return "不及格"
s1.apply(get_grade_from_score)
# Out:
# 小明    A
# 小红    D
# 小杰    D
# 小丽    B
# cc    C
# dtype: object

# %%
import pandas as pd
students=pd.DataFrame({"姓名":["name"],"性别":["gender"],"身高":["height"]})
students
# Out:
#      姓名      性别      身高
# 0  name  gender  height

# %%
数据分析-清洗数据结构性问题
import pandas as pd
对列进行拆分（多出列）split
"28.53万人/0.87平方公里".split（"/"）
df2[["人口“，”面积“]]=df2["人口密度"].str.split("/"，expand=True)
删除原始列drop
df2 = df2.drop("人口密度",axis=1)
df2

把不同列合并成一列cat
df3["姓"].str.cat(df3[[“名"]）
df3["姓"].str.cat(df3[[“名"，sep=“-”]）加拼接符-

把宽数据转换成长数据melt
pd.melt（df4，id_vars=['国家代码'，‘年份'］，var_name='年龄组'，value_name='肺结核病例数'）
id_vars不变的维度；var_name重复数据拉长；value_name；具体数据

对行进行拆分（多出行）
df5.explode（"课程列表"）

对行或列进行删除
df6.drop（"考试2"axis=1)
df6.drop([2,4])
df6.drop(["考试2"，"考试3"］，axis=1）
    df6=df6.drop([2, 4])
    df6.drop([2, 4],inplace=True)

# %% [markdown]
# 数据分析-清洗数据内容性问题——Series or DataFrame
# import pandas as pd
#
# 对某个缺失值进行填充
#     对整列缺失值进行填充
#     dfl[“国家”}=中国
#     df1
#     对某个缺失值进行填充
#     df2.loc["003′销售额"]=800
#     df2
#     对部分缺失值进行填充
#     df3.1oc["003"："004"，"日期"]="2005-01-03"
#     df3
# 缺失值很多，自动找到缺失值进行填充fillna
# df4["B"].fillna（df["B"].mean())
# df4.fillna(0)
# df4.fillna({'A':0,'B':10,'C':20})
#     df4=df4.fillna(0)
#     df4.fillna(0,inplace=True)
#
# 删除存在缺失值的行dropna
# df5.dropna()
# df5.dropna(subset=["工资"]) 检查范围下，工资有缺失，则删除这行
# df5.dropna（axis=1)删除确实的列
#     df5df5.dropna(subset=["工资"])
#     df5.dropna(subset=["工资"],inplace=True)
#
# 删除重复数据drop
# df6["姓名"].drop_duplicates()  删除第二遍出现及其之后的值
# df6.drop_duplicates___所有都重复才删除
# df6.drop_duplicates(subset=['姓名',‘性别'])删除姓名和性别重复的行（注意是同时重复，而而不是某一个重复）
# df6.drop_duplicates(keep='last')
#     df6df6.drop_duplicates()
#     df6.drop_duplicates(inplace=True)
#
# 对值进行替换！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！replace
# df7["学校”].replace（[“清华”，“五道口职业技术学院”，“Tsinghua University”]，“清华大学"）
# 0北京大学
# 1清华大学
# 2华南理工
# 3清华大学
# Name:学校，dtype:object
# df7.replace（[“清华"，“五道口职业技术学院”，“TsinghuaUniversity"]，“清华大学"）
# 姓名家乡学校
# 0小明北京北京大学
# 1小红上海清华大学
# 2小张广州华南理工
# 3小李深圳清华大学
#     df7二df7.replace（"清华"，"清华大学"）
#     df7.replace（"清华"，"清华大学"，inplace=True)
#
# 对值的类型进行转换type-astype
# s1.astype(int)转换成整数
# s1.astype(str)转换成字符串
# s1.astype(float)转换成浮点数
# s1.astype(bool)转换成布尔值
# 可以直接把object当成表示字符串的类型
#
# 对值的类型进行转换_分类数据_数值数据category
# 分类数据有限转为category类型s1.astype("category")

# %%
数据保存to_csv
df1.to_csv("cleaned_sales_data.csv")
默认保存的索引，没有列名，读取时还原索引
cleaned_df.rename(columns={"Unnamed: 0":"销售ID"}, inplace=True)
cleaned_df
cleaned df.set_index（"销售ID"，inplace=True）
cleaned df
保存时CSV不保存索引df1.to_csv("cleaned_sales_data2.csv",index=False)
